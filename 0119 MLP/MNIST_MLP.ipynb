# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import pacakages
# ---

# %%
'''
import modules
  - Basic tool
  - DL tool
  - OS tool
'''
# Basic tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# DL tools
import torch 
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical

# OS tool
import os

# %% [markdown]
# # Device Setting
# ---

# %%
'''
  Setting 
    - Path setting to the current directory
    - GPU device setting (device: cuda)
'''
# Show all columns for the dataframe
pd.set_option('display.max_columns', None)

# Path
my_PATH = "drive/MyDrive/MLP_Assignment"
os.chdir(my_PATH)
# show file list in the current directory
# !dir

'''
 (!!!!!!!!!!!!!!중요!!!!!!!!!!!!!!!!)
 GPU 설정을 해줘야 더 효율적인 학습이 가능합니다.
 "device: cuda"로 출력되면 Good!
 "device: cpu"일 경우 현재 코랩에서'런타임 → 런타임 유형 변경 → GPU' 설정을 해줍시다.
 코랩이 기본제공하는 GPU는 하루 최대 12시간 사용 가능합니다. 런타임이 연결되는 동안 시간이 차감됩니다.
 만약 코랩이 기본제공하는 GPU를 다 썼다면 약 하루를 기다리거나 다른 구글계정을 이용해야합니다. 
'''
# Device setting & configuration
# cuda가 available하면 cuda(GPU)로 아니면 CPU 연결
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('device:', device)
# Out:
# MNIST_MLP.ipynb
# device: cuda

# %% [markdown]
# # Data Load
# ---

# %%
'''
  Load MNIST Data
    - Train & &Validation & Test data 
    - Image and Label
    - Min-Max scaling
'''
# Loading the data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Min-Max scaling
x_train = x_train/255.0
x_test = x_test/255.0

'''
 train_test_split은 sklearn으로 import한 모듈입니다.
 train_test_split을 통해 쉽게 데이터를 분리할 수 있습니다.
 이 코드는 train데이터를 0.8 : 0.2로 train과 validation 데이터로 분리하는 코드입니다,
 print 결과 Train 데이터는 28x28 사이즈의 이미지 데이터가 48,000장 있으며 이미지에 대응하는 label이 48,000개 존재함을 알 수 있습니다.  
'''
# Split train data into Train/Validation data
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, shuffle=True)

# Check data shape
print(f"Train 데이터 크기: {x_train.shape, y_train.shape}")
print(f"Validation 데이터 크기: {x_val.shape, y_val.shape}")
print(f"Test 데이터 크기:{x_test.shape, y_test.shape}")
# Out:
# Train 데이터 크기: ((48000, 28, 28), (48000,))
# Validation 데이터 크기: ((12000, 28, 28), (12000,))
# Test 데이터 크기:((10000, 28, 28), (10000,))

# %%
# Check
fig = plt.figure(figsize=(18,8))
ax1 = fig.add_subplot(211)
img1 = plt.imshow(x_train[0].reshape(28, 28)).set_cmap('Greys')
ax2 = fig.add_subplot(222)
img2 = plt.imshow(x_train[1].reshape(28, 28)).set_cmap('Greys')
print(f"첫번째 이미지 라벨: {y_train[0]} ")
print(f"두번째 이미지 라벨: {y_train[1]} ")
# Out:
# 첫번째 이미지 라벨: 5
# 두번째 이미지 라벨: 2

# %%
'''
  Data Preparation
    - No augmentation
    - Min-Max scaling (already done at the first)    
    - Label(target) -> One hot encoding
    
    MyDataset은 현재 데이터 set에 다음 속성들을 부여합니다.
    Pytorch의 DataLoader를 활용하기 위해 필요합니다.
'''

class Mydataset(torch.utils.data.Dataset):

    # 데이터 전처리 
    def __init__(self, dataX_np , dataY_np):
        self.data_X = dataX_np.astype(np.float32)
        self.data_Y = dataY_np.astype(np.float32) 

        print(f"My_dataset __init__ received : {self.data_X.shape}, {self.data_Y.shape} ")

    # 인덱스를 입력받아 인덱스에 알맞는 입출력 데이터를 Return
    def __getitem__(self, index):
        image = self.data_X[index]
        label = self.data_Y[index]
        # One hot encoding
        # 0~9 숫자로 되어있는 라벨을 one hot encoding 형식으로 변환합니다. 이는 이후 MLP의 출력이 10차원이기에 Loss를 계산하기 위해 진행하였습니다.  
        label = to_categorical(label, num_classes = 10)

        return image, label
    
    # 총 데이터 개수를 Return
    def __len__(self):
        return len(self.data_X)

# %%
'''
 DataLoader는 데이터를 batch_size에 맞게 나눠주거나 shuffle해 주는 등의 기능을 지원합니다.
 DataLoader는 데이터를 index로 접근가능하도록 하고 for문에서 사용할 수 있는 iterable 객체로 감싸줍니다.

 batch_size 변수는 train 데이터의 batch 크기를 결정합니다.
 batch_size를 1로 할 경우 SGD가 되며 (모든 데이터의 배치크기가 1이므로 배치 = 하나의 데이터 이기 떄문입니다)
 batch_size를 현재 데이터의 수보다 같거나 크게 할 경우 BGD가 됩니다. (배치하나가 모든 데이터를 포함하기 때문입니다.)
 현재 batch_size를 32로 설정하였기에 48000//32 = 1500. 1500개의 배치가 생성되며 배치 한개당 32개의 이미지데이터와 라벨데이터가 존재합니다.
 drop_last = False로 설정하여 배치로 나눴을 떄 32개가 채워지지 못하는 마지막 배치를 그대로 살리도록 하였습니다.
 
 train_loader의 경우 batch_size=32로 설정하여 Mini-batch Gradient Descent를 사용하도록 하였습니다. 
 valid_lodaer와 test_loader의 batch_size를 데이터의 수보다 크게하여 모든 데이터에 대한 Loss와 Accuracy가 구해질 수 있도록 하였습니다.

 x_train, x_val, x_test 모두 (-1,28*28)로 reshape하였습니다. 즉, 28x28의 크기로 이뤄진 이미지 데이터를 28*28 = 784 차원의 벡터로 Flatten하였습니다. 이미지 데이터를 일자로 폈다고 생각하시면 됩니다.
 따라서 MLP 모델에 입력되는 데이터는 784차원의 벡터입니다.
'''

batch_size = 32
train_loader = torch.utils.data.DataLoader(Mydataset(x_train.reshape(-1,28*28), y_train), batch_size=batch_size, shuffle=False, drop_last = False)
valid_loader = torch.utils.data.DataLoader(Mydataset(x_val.reshape(-1,28*28), y_val), batch_size = 1000000000, shuffle=False, drop_last = False)
test_loader = torch.utils.data.DataLoader(Mydataset(x_test.reshape(-1,28*28), y_test), batch_size = 100000000, shuffle=False, drop_last = False)
# Out:
# My_dataset __init__ received : (48000, 784), (48000,)
# My_dataset __init__ received : (12000, 784), (12000,)
# My_dataset __init__ received : (10000, 784), (10000,)

# %% [markdown]
# # MLP Model
# ---

# %%
'''
  MLP 모델을 정의하는 Class 입니다.

  self.fc1 에서 fc1은 layer의 이름이며 fc1을 nn.Linear(input_dimension, output_dimension, bias=False)로 정의 할 수 있습니다.
  즉 fc1은 784차원의 input을 wx+b의 Linear 함수를 적용하여 2048차원으로 보냅니다.(input 뉴련 784개, output 뉴런 2048개로 이뤄진 두 layer를 연결합니다.) 
  bias를 True로 설정할 경우 bias를 추가할 수 있습니다.

'''
class MLP_overfit(nn.Module):
    def __init__(self):
        super(MLP_overfit, self).__init__()
        self.fc1 = nn.Linear(784, 2048)
        self.fc3 = nn.Linear(2048, 1024)
        self.fc4 = nn.Linear(1024, 512)
        self.fc5 = nn.Linear(512,256)
        self.fc6 = nn.Linear(256, 128)
        self.fc7 = nn.Linear(128, 64)
        self.fc8 = nn.Linear(64, 10)

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        # x = self.fc2(x)
        # x = F.relu(x) > 이거 빠진 거 아닌가..?
        x = self.fc3(x)
        x = F.relu(x) 
        x = self.fc4(x)
        x = F.relu(x)
        x = self.fc5(x)
        x = F.relu(x) 
        x = self.fc6(x)
        x = F.relu(x) 
        x = self.fc7(x)
        x = F.relu(x)
        x = self.fc8(x)

        # Pytorch에서는 Softmax가 CrossEntropy함수안에 내장되어있기에 없어도 됩니다. 
        # 이후 Loss를 CrossEntropy를 사용할 것이기에 제외하였습니다.
        # x = F.log_softmax(x, dim=1)

        return x

# %%
class MLP_underfit(nn.Module):
    def __init__(self):
        super(MLP_underfit, self).__init__()
        self.fc1 = nn.Linear(784, 4)
        self.fc2 = nn.Linear(4, 10)
        
        # Weight Initialization
        torch.nn.init.xavier_normal_(self.fc1.weight.data, gain=1.0)
        torch.nn.init.xavier_normal_(self.fc2.weight.data, gain=1.0)

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x) 
        x = self.fc2(x)

        return x

# %% [markdown]
# # Train
# ---

# %%
from statistics import mean 
import time

'''
 모델의 학습을 정의하는 함수입니다.
 model, Lossfunction, Optimizer, Scheduler 등을 입력받습니다.
 출력은 train, valdation, test의 loss 리스트로 하였습니다.
 train함수를 사용하면 입력받은 loss와 optimizer, lr scheduler, num_epoch에 따라 model을 학습시킵니다.
'''

def train(model, criterion_, optimizer_, scheduler_, num_epochs=40, first_epoch=1):
    
    train_losses = []
    valid_losses = []
    test_losses = []

    print("----------------------------------------------------------------------------")

    start_time = time.time()
    for epoch in range(first_epoch, first_epoch + num_epochs):
        # train phase
        model.train()
        
        # batch_loss 
        batch_losses = []

        for images, labels in train_loader:
            
            # Move the training data to the GPU
            images = images.to(device)   
            labels = labels.to(device)

            # clear previous gradient computation(이전 그레디언드 계산 지우기)
            optimizer_.zero_grad()

            # forward propagation(순전파)
            outputs = model(images)

            # calculate the loss
            loss = criterion_.forward(outputs, labels)
            batch_losses.append(loss.item())

            # backpropagate to compute gradients(그레이디언트 계산으로 역전파)
            loss.backward()

            # update model weights
            optimizer_.step()

        # Train loss를 저장합니다.
        train_losses.append(mean(batch_losses))

        # validation phase
        # Dropout, BatchNormalization과 같은 layer가 동작하지 않도록 합니다.
        model.eval()

        # We don't need gradients for test, so wrap in 
        # no_grad to save memory
        # 기울기 Gradient를 계산하지 않으며 backpropagation을 하지 않습니다. 
        with torch.no_grad():
            
            correct_test = 0

            for images, labels in valid_loader:

                # Move the training batch to the GPU
                images = images.to(device)
                labels = labels.to(device)

                # forward propagation
                outputs = model(images)

                # calculate the loss
                loss = criterion_(outputs, labels)
                valid_losses.append(loss.item())

            for images, labels in test_loader:
                # Move the training batch to the GPU
                images = images.to(device)
                labels = labels.to(device)

                # forward propagation
                outputs = model(images)

                # calculate the loss
                loss = criterion_(outputs, labels)
                test_losses.append(loss.item())

                # Check Accuracy
                # preds 는 output 중에서 가장 높은 값의 index를 가집니다. 
                _, preds = torch.max(outputs, 1)

                # label이 현재 one hot encoding 형태로 되어있기에 preds를 index로 받아 1인지 확인합니다. 
                # ex) 숫자 2 : label = [0,0,1,0,0,...,0] , label[i][preds] == 1 -> 정답
                for i in range(len(preds)):
                  if labels[i][preds[i]] == 1:
                    correct_test +=1
        
        # 원하는 Epoch마다 결과 출력 
        if (epoch) % 1== 0 :
            curr_time = round(time.time()-start_time)
            train_rec = round(train_losses[-1],5)
            valid_rec = round(valid_losses[-1],5)
            test_rec = round(test_losses[-1],5)
            test_acc = round(100*(correct_test)/len(labels),3)
            print('Epoch', epoch, ' / ',num_epochs)
            print(f"\t [Train loss : {train_rec}]  [Validation loss : {valid_rec}] [Test loss : {test_rec}], [Test Accuracy : {test_acc}%],[curr LR = {scheduler_.get_last_lr()}],[elapsed_time = {curr_time}sec] ")

        # Learning rate Scheduling
        # Scheduler에 따라 learning rate를 조절합니다. 
        scheduler_.step()
        
      
    print(f"\nTrain Ended, total_elapsed_time = {round(time.time()-start_time)} ")
    print("--------------------------------------------------------------------")
    
    # Loss 값 반환
    return train_losses, valid_losses, test_losses

# %% [markdown]
# ## Setting

# %%
# Moodel Setting 
model = MLP_overfit()
model.to(device)

# Optimizer
# Optimzer와 Learning rate를 설정해줍니다.
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Loss Function
criterion = nn.CrossEntropyLoss()

# Learning rate scheduler
# epoch가 10번 돌때마다 learning rate를 gamma만큼 곱해 사용합니다. ex) 0.01 -> 0.005
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Overfitting

# %%
train_losses, valid_losses, test_losses = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=30)
# Out:
# ----------------------------------------------------------------------------
# Epoch 1  /  30
# 	 [Train loss : 0.33684]  [Validation loss : 0.17435] [Test loss : 0.15561], [Test Accuracy : 95.86%],[curr LR = [0.001]],[elapsed_time = 30sec]
# Epoch 2  /  30
# 	 [Train loss : 0.13785]  [Validation loss : 0.14074] [Test loss : 0.12567], [Test Accuracy : 96.85%],[curr LR = [0.001]],[elapsed_time = 48sec]
# Epoch 3  /  30
# 	 [Train loss : 0.09978]  [Validation loss : 0.11887] [Test loss : 0.11834], [Test Accuracy : 97.26%],[curr LR = [0.001]],[elapsed_time = 66sec]
# Epoch 4  /  30
# 	 [Train loss : 0.07851]  [Validation loss : 0.10892] [Test loss : 0.09758], [Test Accuracy : 97.74%],[curr LR = [0.001]],[elapsed_time = 92sec]
# Epoch 5  /  30
# 	 [Train loss : 0.06189]  [Validation loss : 0.1463] [Test loss : 0.12837], [Test Accuracy : 97.32%],[curr LR = [0.001]],[elapsed_time = 109sec]
# Epoch 6  /  30
# 	 [Train loss : 0.05468]  [Validation loss : 0.12571] [Test loss : 0.12418], [Test Accuracy : 97.24%],[curr LR = [0.001]],[elapsed_time = 128sec]
# Epoch 7  /  30
# 	 [Train loss : 0.04858]  [Validation loss : 0.24651] [Test loss : 0.22122], [Test Accuracy : 97.17%],[curr LR = [0.001]],[elapsed_time = 146sec]
# Epoch 8  /  30
# 	 [Train loss : 0.04619]  [Validation loss : 0.16035] [Test loss : 0.14942], [Test Accuracy : 96.99%],[curr LR = [0.001]],[elapsed_time = 164sec]
# Epoch 9  /  30
# 	 [Train loss : 0.03921]  [Validation loss : 0.15463] [Test loss : 0.15002], [Test Accuracy : 97.22%],[curr LR = [0.001]],[elapsed_time = 183sec]
# Epoch 10  /  30
# 	 [Train loss : 0.03505]  [Validation loss : 0.1488] [Test loss : 0.13592], [Test Accuracy : 97.64%],[curr LR = [0.001]],[elapsed_time = 201sec]
# Epoch 11  /  30
# 	 [Train loss : 0.01475]  [Validation loss : 0.1218] [Test loss : 0.10236], [Test Accuracy : 98.29%],[curr LR = [5e-05]],[elapsed_time = 219sec]
# Epoch 12  /  30
# 	 [Train loss : 0.0072]  [Validation loss : 0.13166] [Test loss : 0.10749], [Test Accuracy : 98.38%],[curr LR = [5e-05]],[elapsed_time = 242sec]
# Epoch 13  /  30
# 	 [Train loss : 0.00479]  [Validation loss : 0.14472] [Test loss : 0.11883], [Test Accuracy : 98.41%],[curr LR = [5e-05]],[elapsed_time = 260sec]
# Epoch 14  /  30
# 	 [Train loss : 0.00358]  [Validation loss : 0.1589] [Test loss : 0.12872], [Test Accuracy : 98.4%],[curr LR = [5e-05]],[elapsed_time = 279sec]
# Epoch 15  /  30
# 	 [Train loss : 0.00262]  [Validation loss : 0.17467] [Test loss : 0.14536], [Test Accuracy : 98.42%],[curr LR = [5e-05]],[elapsed_time = 299sec]
# Epoch 16  /  30
# 	 [Train loss : 0.00186]  [Validation loss : 0.19437] [Test loss : 0.15921], [Test Accuracy : 98.42%],[curr LR = [5e-05]],[elapsed_time = 317sec]
# Epoch 17  /  30
# 	 [Train loss : 0.00136]  [Validation loss : 0.21406] [Test loss : 0.1744], [Test Accuracy : 98.53%],[curr LR = [5e-05]],[elapsed_time = 339sec]
# Epoch 18  /  30
# 	 [Train loss : 0.00118]  [Validation loss : 0.23625] [Test loss : 0.18711], [Test Accuracy : 98.47%],[curr LR = [5e-05]],[elapsed_time = 357sec]
# Epoch 19  /  30
# 	 [Train loss : 0.00087]  [Validation loss : 0.25179] [Test loss : 0.20602], [Test Accuracy : 98.46%],[curr LR = [5e-05]],[elapsed_time = 376sec]
# Epoch 20  /  30
# 	 [Train loss : 0.00075]  [Validation loss : 0.27719] [Test loss : 0.22434], [Test Accuracy : 98.47%],[curr LR = [5e-05]],[elapsed_time = 399sec]
# Epoch 21  /  30
# 	 [Train loss : 0.00066]  [Validation loss : 0.27789] [Test loss : 0.22469], [Test Accuracy : 98.48%],[curr LR = [2.5e-06]],[elapsed_time = 421sec]
# Epoch 22  /  30
# 	 [Train loss : 0.00061]  [Validation loss : 0.27952] [Test loss : 0.22574], [Test Accuracy : 98.48%],[curr LR = [2.5e-06]],[elapsed_time = 444sec]
# Epoch 23  /  30
# 	 [Train loss : 0.00057]  [Validation loss : 0.28164] [Test loss : 0.2273], [Test Accuracy : 98.49%],[curr LR = [2.5e-06]],[elapsed_time = 462sec]
# Epoch 24  /  30
# 	 [Train loss : 0.00055]  [Validation loss : 0.28413] [Test loss : 0.22915], [Test Accuracy : 98.47%],[curr LR = [2.5e-06]],[elapsed_time = 480sec]
# Epoch 25  /  30
# 	 [Train loss : 0.00052]  [Validation loss : 0.28703] [Test loss : 0.23134], [Test Accuracy : 98.47%],[curr LR = [2.5e-06]],[elapsed_time = 503sec]
# Epoch 26  /  30
# 	 [Train loss : 0.0005]  [Validation loss : 0.29008] [Test loss : 0.23364], [Test Accuracy : 98.45%],[curr LR = [2.5e-06]],[elapsed_time = 521sec]
# Epoch 27  /  30
# 	 [Train loss : 0.00048]  [Validation loss : 0.29327] [Test loss : 0.23616], [Test Accuracy : 98.44%],[curr LR = [2.5e-06]],[elapsed_time = 540sec]
# Epoch 28  /  30
# 	 [Train loss : 0.00047]  [Validation loss : 0.29651] [Test loss : 0.23879], [Test Accuracy : 98.45%],[curr LR = [2.5e-06]],[elapsed_time = 567sec]
# Epoch 29  /  30
# 	 [Train loss : 0.00045]  [Validation loss : 0.30001] [Test loss : 0.24162], [Test Accuracy : 98.45%],[curr LR = [2.5e-06]],[elapsed_time = 585sec]
# Epoch 30  /  30
# 	 [Train loss : 0.00044]  [Validation loss : 0.30345] [Test loss : 0.24441], [Test Accuracy : 98.45%],[curr LR = [2.5e-06]],[elapsed_time = 603sec]
#
# Train Ended, total_elapsed_time = 603
# --------------------------------------------------------------------

# %% [markdown]
# ### Underfitting

# %%
# Moodel Setting 
model = MLP_underfit()
model.to(device)

# Optimizer
# Optimzer와 Learning rate를 설정해줍니다.
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Loss Function
criterion = nn.CrossEntropyLoss()

# Learning rate scheduler
# epoch가 10번 돌때마다 learning rate를 gamma만큼 곱해 사용합니다. ex) 0.01 -> 0.005
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %%
train_losses_2, valid_losses_2, test_losses_2 = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=20)
# Out:
# ----------------------------------------------------------------------------
# Epoch 1  /  20
# 	 [Train loss : 1.45904]  [Validation loss : 1.08149] [Test loss : 1.08571], [Test Accuracy : 62.78%],[curr LR = [0.001]],[elapsed_time = 24sec]
# Epoch 2  /  20
# 	 [Train loss : 0.81107]  [Validation loss : 0.56279] [Test loss : 0.57004], [Test Accuracy : 83.55%],[curr LR = [0.001]],[elapsed_time = 40sec]
# Epoch 3  /  20
# 	 [Train loss : 0.5442]  [Validation loss : 0.49947] [Test loss : 0.50774], [Test Accuracy : 85.41%],[curr LR = [0.001]],[elapsed_time = 58sec]
# Epoch 4  /  20
# 	 [Train loss : 0.50104]  [Validation loss : 0.4748] [Test loss : 0.48366], [Test Accuracy : 86.09%],[curr LR = [0.001]],[elapsed_time = 79sec]
# Epoch 5  /  20
# 	 [Train loss : 0.48041]  [Validation loss : 0.46211] [Test loss : 0.47096], [Test Accuracy : 86.41%],[curr LR = [0.001]],[elapsed_time = 95sec]
# Epoch 6  /  20
# 	 [Train loss : 0.46824]  [Validation loss : 0.4548] [Test loss : 0.46397], [Test Accuracy : 86.57%],[curr LR = [0.001]],[elapsed_time = 111sec]
# Epoch 7  /  20
# 	 [Train loss : 0.46017]  [Validation loss : 0.45021] [Test loss : 0.45944], [Test Accuracy : 86.58%],[curr LR = [0.001]],[elapsed_time = 127sec]
# Epoch 8  /  20
# 	 [Train loss : 0.45427]  [Validation loss : 0.44719] [Test loss : 0.45643], [Test Accuracy : 86.79%],[curr LR = [0.001]],[elapsed_time = 145sec]
# Epoch 9  /  20
# 	 [Train loss : 0.44974]  [Validation loss : 0.44496] [Test loss : 0.45439], [Test Accuracy : 86.98%],[curr LR = [0.001]],[elapsed_time = 168sec]
# Epoch 10  /  20
# 	 [Train loss : 0.44607]  [Validation loss : 0.44315] [Test loss : 0.45302], [Test Accuracy : 87.09%],[curr LR = [0.001]],[elapsed_time = 183sec]
# Epoch 11  /  20
# 	 [Train loss : 0.43825]  [Validation loss : 0.43987] [Test loss : 0.4483], [Test Accuracy : 87.24%],[curr LR = [0.0005]],[elapsed_time = 200sec]
# Epoch 12  /  20
# 	 [Train loss : 0.43652]  [Validation loss : 0.43905] [Test loss : 0.4477], [Test Accuracy : 87.28%],[curr LR = [0.0005]],[elapsed_time = 219sec]
# Epoch 13  /  20
# 	 [Train loss : 0.43515]  [Validation loss : 0.43835] [Test loss : 0.44716], [Test Accuracy : 87.34%],[curr LR = [0.0005]],[elapsed_time = 235sec]
# Epoch 14  /  20
# 	 [Train loss : 0.43387]  [Validation loss : 0.4377] [Test loss : 0.44673], [Test Accuracy : 87.39%],[curr LR = [0.0005]],[elapsed_time = 255sec]
# Epoch 15  /  20
# 	 [Train loss : 0.43271]  [Validation loss : 0.43714] [Test loss : 0.44647], [Test Accuracy : 87.4%],[curr LR = [0.0005]],[elapsed_time = 274sec]
# Epoch 16  /  20
# 	 [Train loss : 0.43163]  [Validation loss : 0.43669] [Test loss : 0.44609], [Test Accuracy : 87.42%],[curr LR = [0.0005]],[elapsed_time = 290sec]
# Epoch 17  /  20
# 	 [Train loss : 0.43058]  [Validation loss : 0.43622] [Test loss : 0.4456], [Test Accuracy : 87.42%],[curr LR = [0.0005]],[elapsed_time = 306sec]
# Epoch 18  /  20
# 	 [Train loss : 0.42962]  [Validation loss : 0.43583] [Test loss : 0.44519], [Test Accuracy : 87.42%],[curr LR = [0.0005]],[elapsed_time = 325sec]
# Epoch 19  /  20
# 	 [Train loss : 0.42872]  [Validation loss : 0.43546] [Test loss : 0.44501], [Test Accuracy : 87.41%],[curr LR = [0.0005]],[elapsed_time = 345sec]
# Epoch 20  /  20
# 	 [Train loss : 0.42786]  [Validation loss : 0.43515] [Test loss : 0.44488], [Test Accuracy : 87.42%],[curr LR = [0.0005]],[elapsed_time = 361sec]
#
# Train Ended, total_elapsed_time = 361
# --------------------------------------------------------------------

# %% [markdown]
# # Plot Result
# ---

# %%
def plot_result(train_loss, val_loss, test_loss):
  plt.figure(figsize=(20,8))
  plt.plot(train_loss, label='Train Loss', linewidth='3')
  plt.plot(val_loss, label='Validation Loss', linewidth='3')
  plt.plot(test_loss, label='Test Loss', linewidth='3')
  plt.grid()
  plt.rc('xtick', labelsize=12)
  plt.rc('ytick', labelsize=12)  
  plt.legend()
  plt.rc('legend', fontsize=15)  
  plt.xlabel('Number of Eopch')
  plt.ylabel('Cross Entropy Loss')
  plt.rc('axes', labelsize=17)

# %% [markdown]
# #### Overfitting graph

# %%
plot_result(train_losses, valid_losses, test_losses)

# %% [markdown]
# #### Underfitting graph

# %%
plot_result(train_losses_2, valid_losses_2, test_losses_2)

# %% [markdown]
# # Model Save & Load (참고용)
# ---

# %%
''' 
  Modle Save & Load
'''
def save_model_info(model,model_name="ver_1", train_losses=train_losses, valid_losses=valid_losses, test_losses=test_losses):

    if not os.path.isdir("./models"):
        os.makedirs("./models")
    # 모델 정보 저장
    torch.save({'model_state_dict': model.state_dict(),
                'record_list' : [train_losses, valid_losses, test_losses]
                }, f"./models/model_{model_name}.pth") 

    print(f"model_saved : model_{model_name}")


def load_model_info(model_name="ver_1"):

    file_path = f"./models/model_{model_name}.pth"


    if not os.path.exists(file_path):
        print("FATAL ERROR : model path not exist")
    model_info = torch.load(file_path)
    print(f"model_loaded : model_{model_name}")

    model = MLP_underfit()
    model.load_state_dict(model_info['model_state_dict'])
    model.to(device)
    model.eval()

    return model

# %%
save_model_info(model, "underfit", train_losses, valid_losses, test_losses)
# Out:
# model_saved : model_underfit

# %%
model = load_model_info("underfit")
# Out:
# model_loaded : model_underfit

# %% [markdown]
# # Generalized MLP

# %%
class MLP_general(nn.Module):
    def __init__(self):
        super(MLP_general, self).__init__()
        self.fc1 = nn.Linear(784, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
        # Weight Initialization
        #torch.nn.init.xavier_normal_(self.fc1.weight.data, gain=1.0)
        #torch.nn.init.xavier_normal_(self.fc2.weight.data, gain=1.0)

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x) 
        x = self.fc2(x)
        x = F.relu(x) 
        x = self.fc3(x)

        return x

# %%
# Moodel Setting 
model = MLP_general()
model.to(device)

# Optimizer
# Optimzer와 Learning rate를 설정해줍니다.
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Loss Function
criterion = nn.CrossEntropyLoss()

# Learning rate scheduler
# epoch가 10번 돌때마다 learning rate를 gamma만큼 곱해 사용합니다. ex) 0.01 -> 0.005
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %%
train_losses3, valid_losses3, test_losses3 = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=40)
# Out:
# ----------------------------------------------------------------------------
# Epoch 1  /  40
# 	 [Train loss : 0.23327]  [Validation loss : 0.13829] [Test loss : 0.139], [Test Accuracy : 95.84%],[curr LR = [0.001]],[elapsed_time = 27sec]
# Epoch 2  /  40
# 	 [Train loss : 0.09125]  [Validation loss : 0.0902] [Test loss : 0.08967], [Test Accuracy : 97.09%],[curr LR = [0.001]],[elapsed_time = 45sec]
# Epoch 3  /  40
# 	 [Train loss : 0.05645]  [Validation loss : 0.09526] [Test loss : 0.0935], [Test Accuracy : 97.13%],[curr LR = [0.001]],[elapsed_time = 62sec]
# Epoch 4  /  40
# 	 [Train loss : 0.04166]  [Validation loss : 0.09479] [Test loss : 0.09369], [Test Accuracy : 97.46%],[curr LR = [0.001]],[elapsed_time = 83sec]
# Epoch 5  /  40
# 	 [Train loss : 0.03403]  [Validation loss : 0.09225] [Test loss : 0.09318], [Test Accuracy : 97.57%],[curr LR = [0.001]],[elapsed_time = 99sec]
# Epoch 6  /  40
# 	 [Train loss : 0.02644]  [Validation loss : 0.10739] [Test loss : 0.10883], [Test Accuracy : 97.52%],[curr LR = [0.001]],[elapsed_time = 117sec]
# Epoch 7  /  40
# 	 [Train loss : 0.02271]  [Validation loss : 0.1009] [Test loss : 0.09529], [Test Accuracy : 97.6%],[curr LR = [0.001]],[elapsed_time = 133sec]
# Epoch 8  /  40
# 	 [Train loss : 0.02259]  [Validation loss : 0.12229] [Test loss : 0.1166], [Test Accuracy : 97.57%],[curr LR = [0.001]],[elapsed_time = 150sec]
# Epoch 9  /  40
# 	 [Train loss : 0.01915]  [Validation loss : 0.1032] [Test loss : 0.10448], [Test Accuracy : 97.87%],[curr LR = [0.001]],[elapsed_time = 167sec]
# Epoch 10  /  40
# 	 [Train loss : 0.01615]  [Validation loss : 0.11147] [Test loss : 0.09948], [Test Accuracy : 98.03%],[curr LR = [0.001]],[elapsed_time = 185sec]
# Epoch 11  /  40
# 	 [Train loss : 0.00439]  [Validation loss : 0.10045] [Test loss : 0.10687], [Test Accuracy : 98.03%],[curr LR = [0.0005]],[elapsed_time = 204sec]
# Epoch 12  /  40
# 	 [Train loss : 0.0026]  [Validation loss : 0.09619] [Test loss : 0.10914], [Test Accuracy : 98.27%],[curr LR = [0.0005]],[elapsed_time = 225sec]
# Epoch 13  /  40
# 	 [Train loss : 0.00202]  [Validation loss : 0.12045] [Test loss : 0.1195], [Test Accuracy : 98.14%],[curr LR = [0.0005]],[elapsed_time = 242sec]
# Epoch 14  /  40
# 	 [Train loss : 0.0056]  [Validation loss : 0.13042] [Test loss : 0.11765], [Test Accuracy : 98.24%],[curr LR = [0.0005]],[elapsed_time = 259sec]
# Epoch 15  /  40
# 	 [Train loss : 0.00269]  [Validation loss : 0.12535] [Test loss : 0.13213], [Test Accuracy : 98.04%],[curr LR = [0.0005]],[elapsed_time = 279sec]
# Epoch 16  /  40
# 	 [Train loss : 0.00318]  [Validation loss : 0.12545] [Test loss : 0.12646], [Test Accuracy : 98.32%],[curr LR = [0.0005]],[elapsed_time = 296sec]
# Epoch 17  /  40
# 	 [Train loss : 0.00342]  [Validation loss : 0.14092] [Test loss : 0.1509], [Test Accuracy : 98.03%],[curr LR = [0.0005]],[elapsed_time = 317sec]
# Epoch 18  /  40
# 	 [Train loss : 0.00347]  [Validation loss : 0.12303] [Test loss : 0.11413], [Test Accuracy : 98.47%],[curr LR = [0.0005]],[elapsed_time = 333sec]
# Epoch 19  /  40
# 	 [Train loss : 0.00206]  [Validation loss : 0.13058] [Test loss : 0.13006], [Test Accuracy : 98.39%],[curr LR = [0.0005]],[elapsed_time = 351sec]
# Epoch 20  /  40
# 	 [Train loss : 0.00446]  [Validation loss : 0.14607] [Test loss : 0.14372], [Test Accuracy : 98.1%],[curr LR = [0.0005]],[elapsed_time = 375sec]
# Epoch 21  /  40
# 	 [Train loss : 0.00058]  [Validation loss : 0.12379] [Test loss : 0.1272], [Test Accuracy : 98.33%],[curr LR = [0.00025]],[elapsed_time = 391sec]
# Epoch 22  /  40
# 	 [Train loss : 5e-05]  [Validation loss : 0.12422] [Test loss : 0.12495], [Test Accuracy : 98.4%],[curr LR = [0.00025]],[elapsed_time = 410sec]
# Epoch 23  /  40
# 	 [Train loss : 1e-05]  [Validation loss : 0.12459] [Test loss : 0.12574], [Test Accuracy : 98.38%],[curr LR = [0.00025]],[elapsed_time = 427sec]
# Epoch 24  /  40
# 	 [Train loss : 1e-05]  [Validation loss : 0.12555] [Test loss : 0.12714], [Test Accuracy : 98.38%],[curr LR = [0.00025]],[elapsed_time = 447sec]
# Epoch 25  /  40
# 	 [Train loss : 1e-05]  [Validation loss : 0.12739] [Test loss : 0.12903], [Test Accuracy : 98.43%],[curr LR = [0.00025]],[elapsed_time = 468sec]
# Epoch 26  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.13002] [Test loss : 0.13175], [Test Accuracy : 98.48%],[curr LR = [0.00025]],[elapsed_time = 487sec]
# Epoch 27  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.1335] [Test loss : 0.13535], [Test Accuracy : 98.48%],[curr LR = [0.00025]],[elapsed_time = 504sec]
# Epoch 28  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.13838] [Test loss : 0.14031], [Test Accuracy : 98.45%],[curr LR = [0.00025]],[elapsed_time = 525sec]
# Epoch 29  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.14255] [Test loss : 0.14452], [Test Accuracy : 98.46%],[curr LR = [0.00025]],[elapsed_time = 545sec]
# Epoch 30  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.14727] [Test loss : 0.14917], [Test Accuracy : 98.49%],[curr LR = [0.00025]],[elapsed_time = 561sec]
# Epoch 31  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.14975] [Test loss : 0.15141], [Test Accuracy : 98.5%],[curr LR = [0.000125]],[elapsed_time = 583sec]
# Epoch 32  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.15351] [Test loss : 0.15534], [Test Accuracy : 98.51%],[curr LR = [0.000125]],[elapsed_time = 600sec]
# Epoch 33  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.15781] [Test loss : 0.16006], [Test Accuracy : 98.52%],[curr LR = [0.000125]],[elapsed_time = 619sec]
# Epoch 34  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.1622] [Test loss : 0.16464], [Test Accuracy : 98.5%],[curr LR = [0.000125]],[elapsed_time = 636sec]
# Epoch 35  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.16641] [Test loss : 0.16888], [Test Accuracy : 98.49%],[curr LR = [0.000125]],[elapsed_time = 653sec]
# Epoch 36  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.17004] [Test loss : 0.17268], [Test Accuracy : 98.48%],[curr LR = [0.000125]],[elapsed_time = 673sec]
# Epoch 37  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.17298] [Test loss : 0.1756], [Test Accuracy : 98.46%],[curr LR = [0.000125]],[elapsed_time = 690sec]
# Epoch 38  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.17531] [Test loss : 0.17789], [Test Accuracy : 98.47%],[curr LR = [0.000125]],[elapsed_time = 707sec]
# Epoch 39  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.17744] [Test loss : 0.17993], [Test Accuracy : 98.48%],[curr LR = [0.000125]],[elapsed_time = 721sec]
# Epoch 40  /  40
# 	 [Train loss : 0.0]  [Validation loss : 0.17888] [Test loss : 0.1812], [Test Accuracy : 98.46%],[curr LR = [0.000125]],[elapsed_time = 740sec]
#
# Train Ended, total_elapsed_time = 740
# --------------------------------------------------------------------

# %%
plot_result(train_losses3, valid_losses3, test_losses3 )
